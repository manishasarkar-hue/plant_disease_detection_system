# %%
print("PlantGuard AI 🌱")
# Out:
# PlantGuard AI 🌱

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
# Out:
# NumPy: 2.4.6
# Pandas: 3.0.5
